# %% [markdown]
# ## Differnet Criteria:
# Simple criteria are:
# - Budget Focus: Lowest Prices, Tolerant Crowd, Less than ideal perfect condition
# - Family Focus: Seek balances between cost and convients, avoid extreme crows and wheather, value amentites and beginner and intermeidate terrian
# - Expert/ Snow enthusiast: Prioritized Ideal snow condition and challenging terrain . less prices and crowds
#
# Mt. Baw Baw	Mt. Stirling	Mt. Hotham	Falls Creek	Mt. Buller	Selwyn	Thredbo	Perisher	Charlotte Pass

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stat = pd.read_csv("moutain_stat.csv")

# %%
stat
# Out:
#                Resort Highest Lifted Point Lowest Lifted Point Skiable Area  \
# 0            Perisher                2034m               1605m       1245ha
# 1             Thredbo                2037m               1365m        480ha
# 2  Selwyn Snow Resort                1614m               1492m         45ha
# 3      Charlotte Pass                1955m               1760m         50ha
# 4           Mt Buller                1805m               1375m        300ha
# 5           Mt Hotham                1945m               1450m        320ha
# 6         Falls Creek                1780m               1500m        450ha
# 7        Corin Forest                1220m               1210m          1ha
# 8          Mt Baw Baw                1562m               1407m         30ha
# 9          Ben Lomond                1570m               1470m         29ha
#
#   Snow Making Area  Lifts Terrain Advanced Terrain Intermediate  \
# 0           53.4ha     47              18%                  60%
# 1             70ha     14              17%                  67%
# 2             36ha     11              12%                  48%
# 3             10ha      6              20%                  50%
# 4            70ha+     22              35%                  45%
# 5             25ha     13              40%                  40%
# 6            100ha     15              28%                  49%
# 7              1ha      2               0%                   0%
# 8             10ha      7              11%                  64%
# 9              2ha      6              15%                  45%
#
#   Terrain Beginner
# 0              22%
# 1              16%
# 2              40%
# 3              30%
# 4              20%
# 5              20%
# 6              23%
# 7             100%
# 8              25%
# 9              40%
